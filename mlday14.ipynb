# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("market_basket.csv" , header = None)
df.head(2)
# Out:
#         0          1        2               3             4   \
# 0   shrimp    almonds  avocado  vegetables mix  green grapes
# 1  burgers  meatballs     eggs             NaN           NaN
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5975 sha256=8cda9fe7cf370b92e769f87288f989862c883703216b0084309da4e5ff5c0694
#   Stored in directory: c:\users\ks761\appdata\local\pip\cache\wheels\77\3d\a6\d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
# Data Processing
transactions = []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset
from apyori import apriori
rules = apriori(transactions ,
              min_support = 0.003 ,     #(3items * 7 days in week)/(Total Rows in dataset 7501)
              min_confidence = 0.2 ,
              min_left = 3 ,
              min_length = 2)

#Visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0 , len(a))]

# %%
# a

# %%
result
# Out:
# [['mineral water'],
#  ['nan'],
#  ['almonds', 'burgers'],
#  ['almonds', 'chocolate'],
#  ['eggs', 'almonds'],
#  ['almonds', 'french fries'],
#  ['green tea', 'almonds'],
#  ['almonds', 'milk'],
#  ['mineral water', 'almonds'],
#  ['nan', 'almonds'],
#  ['spaghetti', 'almonds'],
#  ['nan', 'antioxydant juice'],
#  ['nan', 'asparagus'],
#  ['avocado', 'chocolate'],
#  ['avocado', 'french fries'],
#  ['avocado', 'milk'],
#  ['mineral water', 'avocado'],
#  ['nan', 'avocado'],
#  ['spaghetti', 'avocado'],
#  ['nan', 'babies food'],
#  ['mineral water', 'bacon'],
#  ['nan', 'bacon'],
#  ['spaghetti', 'bacon'],
#  ['eggs', 'barbecue sauce'],
#  ['mineral water', 'barbecue sauce'],
#  ['nan', 'barbecue sauce'],
#  ['eggs', 'black tea'],
#  ['black tea', 'milk'],
#  ['mineral water', 'black tea'],
#  ['nan', 'black tea'],
#  ['spaghetti', 'black tea'],
#  ['mineral water', 'blueberries'],
#  ['nan', 'blueberries'],
#  ['spaghetti', 'blueberries'],
#  ['body spray', 'french fries'],
#  ['mineral water', 'body spray'],
#  ['nan', 'body spray'],
#  ['eggs', 'brownies'],
#  ['brownies', 'french fries'],
#  ['mineral water', 'brownies'],
#  ['nan', 'brownies'],
#  ['spaghetti', 'brownies'],
#  ['nan', 'bug spray'],
#  ['burger sauce', 'nan'],
#  ['eggs', 'burgers'],
#  ['burgers', 'french fries'],
#  ['green tea', 'burgers'],
#  ['ham', 'burgers'],
#  ['burgers', 'milk'],
#  ['mineral water', 'burgers'],
#  ['nan', 'burgers'],
#  ['spaghetti', 'burgers'],
#  ['butter', 'chocolate'],
#  ['eggs', 'butter'],
#  ['butter', 'french fries'],
#  ['green tea', 'butter'],
#  ['butter', 'milk'],
#  ['nan', 'butter'],
#  ['spaghetti', 'butter'],
#  ['cake', 'eggs'],
#  ['cake', 'french fries'],
#  ['cake', 'mineral water'],
#  ['cake', 'nan'],
#  ['cake', 'spaghetti'],
#  ['nan', 'candy bars'],
#  ['chocolate', 'carrots'],
#  ['green tea', 'carrots'],
#  ['mineral water', 'carrots'],
#  ['nan', 'carrots'],
#  ['spaghetti', 'carrots'],
#  ['nan', 'cauliflower'],
#  ['cereals', 'chocolate'],
#  ['green tea', 'cereals'],
#  ['cereals', 'milk'],
#  ['mineral water', 'cereals'],
#  ['nan', 'cereals'],
#  ['spaghetti', 'cereals'],
#  ['champagne', 'chocolate'],
#  ['nan', 'champagne'],
#  ['chicken', 'chocolate'],
#  ['chicken', 'eggs'],
#  ['chicken', 'light cream'],
#  ['chicken', 'milk'],
#  ['mineral water', 'chicken'],
#  ['nan', 'chicken'],
#  ['spaghetti', 'chicken'],
#  ['nan', 'chili'],
#  ['cooking oil', 'chocolate'],
#  ['eggs', 'chocolate'],
#  ['escalope', 'chocolate'],
#  ['chocolate', 'french fries'],
#  ['french wine', 'chocolate'],
#  ['fresh bread', 'chocolate'],
#  ['fresh tuna', 'chocolate'],
#  ['fromage blanc', 'chocolate'],
#  ['chocolate', 'frozen smoothie'],
#  ['frozen vegetables', 'chocolate'],
#  ['grated cheese', 'chocolate'],
#  ['ground beef', 'chocolate'],
#  ['ham', 'chocolate'],
#  ['chocolate', 'light cream'],
#  ['chocolate', 'milk'],
#  ['mineral water', 'chocolate'],
#  ['mushroom cream sauce', 'chocolate'],
#  ['nan', 'chocolate'],
#  ['oil', 'chocolate'],
#  ['olive oil', 'chocolate'],
#  ['pancakes', 'chocolate'],
#  ['parmesan cheese', 'chocolate'],
#  ['pepper', 'chocolate'],
#  ['chocolate', 'rice'],
#  ['salmon', 'chocolate'],
#  ['shrimp', 'chocolate'],
#  ['soup', 'chocolate'],
#  ['spaghetti', 'chocolate'],
#  ['tomato sauce', 'chocolate'],
#  ['tomatoes', 'chocolate'],
#  ['white wine', 'chocolate'],
#  ['whole wheat pasta', 'chocolate'],
#  ['whole wheat rice', 'chocolate'],
#  ['nan', 'chocolate bread'],
#  ['nan', 'chutney'],
#  ['eggs', 'cider'],
#  ['cider', 'milk'],
#  ['nan', 'cider'],
#  ['nan', 'clothes accessories'],
#  ['cookies', 'nan'],
#  ['cooking oil', 'eggs'],
#  ['cooking oil', 'milk'],
#  ['mineral water', 'cooking oil'],
#  ['nan', 'cooking oil'],
#  ['spaghetti', 'cooking oil'],
#  ['corn', 'nan'],
#  ['cottage cheese', 'green tea'],
#  ['mineral water', 'cottage cheese'],
#  ['nan', 'cottage cheese'],
#  ['spaghetti', 'cottage cheese'],
#  ['nan', 'dessert wine'],
#  ['eggs', 'eggplant'],
#  ['mineral water', 'eggplant'],
#  ['nan', 'eggplant'],
#  ['spaghetti', 'eggplant'],
#  ['eggs', 'french fries'],
#  ['french wine', 'eggs'],
#  ['fresh bread', 'eggs'],
#  ['fresh tuna', 'eggs'],
#  ['eggs', 'fromage blanc'],
#  ['frozen vegetables', 'eggs'],
#  ['eggs', 'ground beef'],
#  ['ham', 'eggs'],
#  ['eggs', 'herb & pepper'],
#  ['eggs', 'light cream'],
#  ['light mayo', 'eggs'],
#  ['eggs', 'low fat yogurt'],
#  ['eggs', 'meatballs'],
#  ['eggs', 'milk'],
#  ['mineral water', 'eggs'],
#  ['nan', 'eggs'],
#  ['pancakes', 'eggs'],
#  ['parmesan cheese', 'eggs'],
#  ['eggs', 'red wine'],
#  ['spaghetti', 'eggs'],
#  ['eggs', 'turkey'],
#  ['energy bar', 'milk'],
#  ['mineral water', 'energy bar'],
#  ['nan', 'energy bar'],
#  ['energy drink', 'french fries'],
#  ['mineral water', 'energy drink'],
#  ['nan', 'energy drink'],
#  ['escalope', 'french fries'],
#  ['mineral water', 'escalope'],
#  ['escalope', 'mushroom cream sauce'],
#  ['nan', 'escalope'],
#  ['pasta', 'escalope'],
#  ['mineral water', 'extra dark chocolate'],
#  ['nan', 'extra dark chocolate'],
#  ['spaghetti', 'extra dark chocolate'],
#  ['flax seed', 'green tea'],
#  ['nan', 'flax seed'],
#  ['fromage blanc', 'french fries'],
#  ['frozen smoothie', 'french fries'],
#  ['green tea', 'french fries'],
#  ['ham', 'french fries'],
#  ['hot dogs', 'french fries'],
#  ['light mayo', 'french fries'],
#  ['muffins', 'french fries'],
#  ['mushroom cream sauce', 'french fries'],
#  ['nan', 'french fries'],
#  ['pancakes', 'french fries'],
#  ['rice', 'french fries'],
#  ['strawberries', 'french fries'],
#  ['tomato juice', 'french fries'],
#  ['vegetables mix', 'french fries'],
#  ['french wine', 'milk'],
#  ['mineral water', 'french wine'],
#  ['nan', 'french wine'],
#  ['spaghetti', 'french wine'],
#  ['fresh bread', 'milk'],
#  ['mineral water', 'fresh bread'],
#  ['nan', 'fresh bread'],
#  ['spaghetti', 'fresh bread'],
#  ['fresh tuna', 'milk'],
#  ['mineral water', 'fresh tuna'],
#  ['nan', 'fresh tuna'],
#  ['fresh tuna', 'pancakes'],
#  ['spaghetti', 'fresh tuna'],
#  ['honey', 'fromage blanc'],
#  ['mineral water', 'fromage blanc'],
#  ['nan', 'fromage blanc'],
#  ['spaghetti', 'fromage blanc'],
#  ['milk', 'frozen smoothie'],
#  ['mineral water', 'frozen smoothie'],
#  ['nan', 'frozen smoothie'],
#  ['spaghetti', 'frozen smoothie'],
#  ['frozen vegetables', 'milk'],
#  ['frozen vegetables', 'mineral water'],
#  ['frozen vegetables', 'nan'],
#  ['frozen vegetables', 'parmesan cheese'],
#  ['frozen vegetables', 'shrimp'],
#  ['frozen vegetables', 'spaghetti'],
#  ['frozen vegetables', 'tomatoes'],
#  ['nan', 'gluten free bar'],
#  ['grated cheese', 'ground beef'],
#  ['grated cheese', 'mineral water'],
#  ['grated cheese', 'nan'],
#  ['grated cheese', 'spaghetti'],
#  ['green beans', 'nan'],
#  ['green beans', 'spaghetti'],
#  ['mineral water', 'green grapes'],
#  ['nan', 'green grapes'],
#  ['green tea', 'gums'],
#  ['hot dogs', 'green tea'],
#  ['mineral water', 'green tea'],
#  ['nan', 'green tea'],
#  ['spaghetti', 'green tea'],
#  ['green tea', 'tomato juice'],
#  ['ground beef', 'herb & pepper'],
#  ['ground beef', 'light cream'],
#  ['ground beef', 'milk'],
#  ['mineral water', 'ground beef'],
#  ['nan', 'ground beef'],
#  ['olive oil', 'ground beef'],
#  ['pepper', 'ground beef'],
#  ['ground beef', 'rice'],
#  ['salmon', 'ground beef'],
#  ['spaghetti', 'ground beef'],
#  ['tomato sauce', 'ground beef'],
#  ['mineral water', 'gums'],
#  ['nan', 'gums'],
#  ['spaghetti', 'gums'],
#  ['mineral water', 'ham'],
#  ['nan', 'ham'],
#  ['spaghetti', 'ham'],
#  ['nan', 'hand protein bar'],
#  ['mineral water', 'herb & pepper'],
#  ['nan', 'herb & pepper'],
#  ['spaghetti', 'herb & pepper'],
#  ['honey', 'mineral water'],
#  ['honey', 'nan'],
#  ['honey', 'spaghetti'],
#  ['mineral water', 'hot dogs'],
#  ['nan', 'hot dogs'],
#  ['spaghetti', 'hot dogs'],
#  ['nan', 'ketchup'],
#  ['milk', 'light cream'],
#  ['mineral water', 'light cream'],
#  ['nan', 'light cream'],
#  ['olive oil', 'light cream'],
#  ['pancakes', 'light cream'],
#  ['spaghetti', 'light cream'],
#  ['mineral water', 'light mayo'],
#  ['nan', 'light mayo'],
#  ['light mayo', 'pancakes'],
#  ['mineral water', 'low fat yogurt'],
#  ['nan', 'low fat yogurt'],
#  ['mineral water', 'magazines'],
#  ['nan', 'magazines'],
#  ['mashed potato', 'nan'],
#  ['nan', 'mayonnaise'],
#  ['meatballs', 'milk'],
#  ['mineral water', 'meatballs'],
#  ['nan', 'meatballs'],
#  ['spaghetti', 'meatballs'],
#  ['nan', 'melons'],
#  ['mineral water', 'milk'],
#  ['nan', 'milk'],
#  ['olive oil', 'milk'],
#  ['salmon', 'milk'],
#  ['shrimp', 'milk'],
#  ['soup', 'milk'],
#  ['spaghetti', 'milk'],
#  ['tomatoes', 'milk'],
#  ['white wine', 'milk'],
#  ['whole wheat pasta', 'milk'],
#  ['whole wheat rice', 'milk'],
#  ['mineral water', 'mint'],
#  ['mineral water', 'nan'],
#  ['mineral water', 'nonfat milk'],
#  ['mineral water', 'oil'],
#  ['mineral water', 'olive oil'],
#  ['mineral water', 'pancakes'],
#  ['mineral water', 'parmesan cheese'],
#  ['mineral water', 'pepper'],
#  ['mineral water', 'protein bar'],
#  ['mineral water', 'red wine'],
#  ['mineral water', 'rice'],
#  ['mineral water', 'salmon'],
#  ['mineral water', 'shrimp'],
#  ['mineral water', 'soup'],
#  ['mineral water', 'spaghetti'],
#  ['mineral water', 'strawberries'],
#  ['mineral water', 'strong cheese'],
#  ['mineral water', 'tomato juice'],
#  ['mineral water', 'tomato sauce'],
#  ['mineral water', 'tomatoes'],
#  ['mineral water', 'turkey'],
#  ['mineral water', 'vegetables mix'],
#  ['mineral water', 'white wine'],
#  ['mineral water', 'whole weat flour'],
#  ['mineral water', 'whole wheat pasta'],
#  ['mineral water', 'whole wheat rice'],
#  ['mineral water', 'yams'],
#  ['mineral water', 'yogurt cake'],
#  ['mineral water', 'zucchini'],
#  ['nan', 'mint'],
#  ['spaghetti', 'mint'],
#  ['nan', 'mint green tea'],
#  ['muffins', 'nan'],
#  ['nan', 'mushroom cream sauce'],
#  ['spaghetti', 'mushroom cream sauce'],
#  ['nan', 'nonfat milk'],
#  ['nan', 'oatmeal'],
#  ['nan', 'oil'],
#  ['nan', 'olive oil'],
#  ['nan', 'pancakes'],
#  ['nan', 'parmesan cheese'],
#  ['nan', 'pasta'],
#  ['nan', 'pepper'],
#  ['nan', 'pet food'],
#  ['nan', 'pickles'],
#  ['nan', 'protein bar'],
#  ['nan', 'red wine'],
#  ['nan', 'rice'],
#  ['nan', 'salad'],
#  ['nan', 'salmon'],
#  ['nan', 'salt'],
#  ['nan', 'sandwich'],
#  ['nan', 'shallot'],
#  ['nan', 'shampoo'],
#  ['nan', 'shrimp'],
#  ['nan', 'soda'],
#  ['nan', 'soup'],
#  ['nan', 'spaghetti'],
#  ['nan', 'sparkling water'],
#  ['nan', 'spinach'],
#  ['nan', 'strawberries'],
#  ['nan', 'strong cheese'],
#  ['nan', 'tea'],
#  ['nan', 'tomato juice'],
#  ['nan', 'tomato sauce'],
#  ['nan', 'tomatoes'],
#  ['nan', 'toothpaste'],
#  ['nan', 'turkey'],
#  ['nan', 'vegetables mix'],
#  ['nan', 'white wine'],
#  ['nan', 'whole weat flour'],
#  ['nan', 'whole wheat pasta'],
#  ['nan', 'whole wheat rice'],
#  ['nan', 'yams'],
#  ['nan', 'yogurt cake'],
#  ['nan', 'zucchini'],
#  ['nonfat milk', 'spaghetti'],
#  ['spaghetti', 'oil'],
#  ['spaghetti', 'olive oil'],
#  ['whole wheat pasta', 'olive oil'],
#  ['spaghetti', 'pancakes'],
#  ['spaghetti', 'parmesan cheese'],
#  ['pasta', 'shrimp'],
#  ['spaghetti', 'pepper'],
#  ['spaghetti', 'protein bar'],
#  ['spaghetti', 'red wine'],
#  ['spaghetti', 'rice'],
#  ['spaghetti', 'salmon'],
#  ['spaghetti', 'shrimp'],
#  ['spaghetti', 'soup'],
#  ['spaghetti', 'strong cheese'],
#  ['spaghetti', 'tomato juice'],
#  ['spaghetti', 'tomato sauce'],
#  ['spaghetti', 'tomatoes'],
#  ['spaghetti', 'turkey'],
#  ['spaghetti', 'vegetables mix'],
#  ['spaghetti', 'white wine'],
#  ['spaghetti', 'whole wheat pasta'],
#  ['spaghetti', 'whole wheat rice'],
#  ['spaghetti', 'zucchini'],
#  ['nan', 'almonds', 'burgers'],
#  ['cake', 'nan', 'almonds'],
#  ['nan', 'almonds', 'chocolate'],
#  ['nan', 'eggs', 'almonds'],
#  ['nan', 'almonds', 'french fries'],
#  ['frozen vegetables', 'nan', 'almonds'],
#  ['nan', 'green tea', 'almonds'],
#  ['nan', 'almonds', 'ground beef'],
#  ['nan', 'almonds', 'milk'],
#  ['mineral water', 'nan', 'almonds'],
#  ['nan', 'pancakes', 'almonds'],
#  ['nan', 'spaghetti', 'almonds'],
#  ['nan', 'avocado', 'burgers'],
#  ['cake', 'nan', 'avocado'],
#  ['mineral water', 'avocado', 'chocolate'],
#  ['nan', 'avocado', 'chocolate'],
#  ['eggs', 'nan', 'avocado'],
#  ['nan', 'avocado', 'french fries'],
#  ['nan', 'avocado', 'frozen smoothie'],
#  ['frozen vegetables', 'nan', 'avocado'],
#  ['nan', 'green tea', 'avocado'],
#  ['nan', 'avocado', 'ground beef'],
#  ['honey', 'nan', 'avocado'],
#  ['mineral water', 'avocado', 'milk'],
#  ['nan', 'avocado', 'milk'],
#  ['spaghetti', 'avocado', 'milk'],
#  ['mineral water', 'nan', 'avocado'],
#  ['nan', 'avocado', 'olive oil'],
#  ['nan', 'pancakes', 'avocado'],
#  ['nan', 'soup', 'avocado'],
#  ['nan', 'avocado', 'spaghetti'],
#  ['nan', 'avocado', 'tomatoes'],
#  ['nan', 'avocado', 'turkey'],
#  ['nan', 'avocado', 'whole wheat rice'],
#  ['mineral water', 'bacon', 'nan'],
#  ['nan', 'bacon', 'spaghetti'],
#  ['eggs', 'nan', 'barbecue sauce'],
#  ['mineral water', 'nan', 'barbecue sauce'],
#  ['nan', 'eggs', 'black tea'],
#  ['nan', 'black tea', 'milk'],
#  ['mineral water', 'nan', 'black tea'],
#  ['nan', 'spaghetti', 'black tea'],
#  ['mineral water', 'nan', 'blueberries'],
#  ['nan', 'spaghetti', 'blueberries'],
#  ['nan', 'body spray', 'french fries'],
#  ['mineral water', 'nan', 'body spray'],
#  ['nan', 'burgers', 'brownies'],
#  ['cake', 'nan', 'brownies'],
#  ['nan', 'chocolate', 'brownies'],
#  ['nan', 'cottage cheese', 'brownies'],
#  ['mineral water', 'eggs', 'brownies'],
#  ['nan', 'eggs', 'brownies'],
#  ['nan', 'brownies', 'french fries'],
#  ['frozen vegetables', 'nan', 'brownies'],
#  ['nan', 'green tea', 'brownies'],
#  ['nan', 'ground beef', 'brownies'],
#  ['nan', 'low fat yogurt', 'brownies'],
#  ['nan', 'brownies', 'milk'],
#  ['mineral water', 'nan', 'brownies'],
#  ['nan', 'olive oil', 'brownies'],
#  ['nan', 'pancakes', 'brownies'],
#  ['nan', 'shrimp', 'brownies'],
#  ['nan', 'spaghetti', 'brownies'],
#  ['nan', 'burgers', 'butter'],
#  ['cake', 'burgers', 'chocolate'],
#  ['cake', 'eggs', 'burgers'],
#  ['cake', 'burgers', 'milk'],
#  ['cake', 'burgers', 'mineral water'],
#  ['cake', 'nan', 'burgers'],
#  ['nan', 'cereals', 'burgers'],
#  ['nan', 'burgers', 'champagne'],
#  ['nan', 'chicken', 'burgers'],
#  ['eggs', 'burgers', 'chocolate'],
#  ['burgers', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'burgers', 'chocolate'],
#  ['green tea', 'burgers', 'chocolate'],
#  ['burgers', 'ground beef', 'chocolate'],
#  ['burgers', 'chocolate', 'milk'],
#  ['mineral water', 'burgers', 'chocolate'],
#  ['nan', 'burgers', 'chocolate'],
#  ['pancakes', 'burgers', 'chocolate'],
#  ['shrimp', 'burgers', 'chocolate'],
#  ['spaghetti', 'burgers', 'chocolate'],
#  ['turkey', 'burgers', 'chocolate'],
#  ['cookies', 'nan', 'burgers'],
#  ['nan', 'cooking oil', 'burgers'],
#  ['nan', 'cottage cheese', 'burgers'],
#  ['eggs', 'burgers', 'french fries'],
#  ['green tea', 'eggs', 'burgers'],
#  ['eggs', 'burgers', 'ground beef'],
#  ['eggs', 'burgers', 'milk'],
#  ['mineral water', 'eggs', 'burgers'],
#  ['nan', 'eggs', 'burgers'],
#  ['pancakes', 'eggs', 'burgers'],
#  ['spaghetti', 'eggs', 'burgers'],
#  ['eggs', 'burgers', 'turkey'],
#  ['nan', 'escalope', 'burgers'],
#  ['green tea', 'burgers', 'french fries'],
#  ['burgers', 'milk', 'french fries'],
#  ['mineral water', 'burgers', 'french fries'],
#  ['nan', 'burgers', 'french fries'],
#  ['pancakes', 'burgers', 'french fries'],
#  ['spaghetti', 'burgers', 'french fries'],
#  ['nan', 'french wine', 'burgers'],
#  ['nan', 'fresh bread', 'burgers'],
#  ['nan', 'fresh tuna', 'burgers'],
#  ['mineral water', 'burgers', 'frozen smoothie'],
#  ['nan', 'burgers', 'frozen smoothie'],
#  ['frozen vegetables', 'burgers', 'mineral water'],
#  ['frozen vegetables', 'nan', 'burgers'],
#  ['frozen vegetables', 'spaghetti', 'burgers'],
#  ['grated cheese', 'nan', 'burgers'],
#  ['green tea', 'burgers', 'milk'],
#  ['nan', 'green tea', 'burgers'],
#  ['spaghetti', 'green tea', 'burgers'],
#  ['burgers', 'ground beef', 'milk'],
#  ['mineral water', 'burgers', 'ground beef'],
#  ['nan', 'burgers', 'ground beef'],
#  ['spaghetti', 'burgers', 'ground beef'],
#  ['nan', 'ham', 'burgers'],
#  ['nan', 'burgers', 'herb & pepper'],
#  ['honey', 'nan', 'burgers'],
#  ['nan', 'hot dogs', 'burgers'],
#  ['nan', 'light mayo', 'burgers'],
#  ['nan', 'burgers', 'low fat yogurt'],
#  ['mineral water', 'burgers', 'milk'],
#  ['nan', 'burgers', 'milk'],
#  ['spaghetti', 'burgers', 'milk'],
#  ['turkey', 'burgers', 'milk'],
#  ['burgers', 'whole wheat rice', 'milk'],
#  ['mineral water', 'nan', 'burgers'],
#  ['mineral water', 'burgers', 'olive oil'],
#  ['mineral water', 'pancakes', 'burgers'],
#  ['mineral water', 'shrimp', 'burgers'],
#  ['mineral water', 'spaghetti', 'burgers'],
#  ['mineral water', 'burgers', 'tomatoes'],
#  ['mineral water', 'turkey', 'burgers'],
#  ['mineral water', 'burgers', 'whole wheat rice'],
#  ['nan', 'burgers', 'olive oil'],
#  ['nan', 'pancakes', 'burgers'],
#  ['nan', 'burgers', 'red wine'],
#  ['nan', 'salmon', 'burgers'],
#  ['nan', 'shrimp', 'burgers'],
#  ['nan', 'soup', 'burgers'],
#  ['nan', 'spaghetti', 'burgers'],
#  ['nan', 'burgers', 'tomato juice'],
#  ['nan', 'burgers', 'tomatoes'],
#  ['nan', 'turkey', 'burgers'],
#  ['nan', 'whole wheat pasta', 'burgers'],
#  ['nan', 'burgers', 'whole wheat rice'],
#  ['spaghetti', 'pancakes', 'burgers'],
#  ['spaghetti', 'turkey', 'burgers'],
#  ['spaghetti', 'burgers', 'whole wheat rice'],
#  ['nan', 'chicken', 'butter'],
#  ['nan', 'butter', 'chocolate'],
#  ['nan', 'cooking oil', 'butter'],
#  ['nan', 'eggs', 'butter'],
#  ['nan', 'butter', 'french fries'],
#  ['frozen vegetables', 'nan', 'butter'],
#  ['grated cheese', 'nan', 'butter'],
#  ['nan', 'green tea', 'butter'],
#  ['nan', 'butter', 'ground beef'],
#  ['nan', 'butter', 'low fat yogurt'],
#  ['nan', 'butter', 'milk'],
#  ['mineral water', 'nan', 'butter'],
#  ['nan', 'pancakes', 'butter'],
#  ['nan', 'shrimp', 'butter'],
#  ['nan', 'spaghetti', 'butter'],
#  ['nan', 'butter', 'tomatoes'],
#  ['nan', 'butter', 'whole wheat rice'],
#  ['cake', 'nan', 'cereals'],
#  ['cake', 'chicken', 'mineral water'],
#  ['cake', 'nan', 'chicken'],
#  ['cake', 'eggs', 'chocolate'],
#  ['cake', 'chocolate', 'french fries'],
#  ['cake', 'chocolate', 'milk'],
#  ['cake', 'mineral water', 'chocolate'],
#  ['cake', 'nan', 'chocolate'],
#  ['cake', 'spaghetti', 'chocolate'],
#  ['cake', 'nan', 'cookies'],
#  ['cake', 'cooking oil', 'nan'],
#  ['cake', 'cottage cheese', 'nan'],
#  ['cake', 'eggs', 'french fries'],
#  ['cake', 'green tea', 'eggs'],
#  ['cake', 'eggs', 'milk'],
#  ['cake', 'eggs', 'mineral water'],
#  ['cake', 'nan', 'eggs'],
#  ['cake', 'pancakes', 'eggs'],
#  ['cake', 'eggs', 'spaghetti'],
#  ['cake', 'eggs', 'turkey'],
#  ['cake', 'nan', 'energy bar'],
#  ['cake', 'nan', 'energy drink'],
#  ['cake', 'nan', 'escalope'],
#  ['cake', 'green tea', 'french fries'],
#  ['cake', 'milk', 'french fries'],
#  ['cake', 'mineral water', 'french fries'],
#  ['cake', 'nan', 'french fries'],
#  ['cake', 'spaghetti', 'french fries'],
#  ['cake', 'nan', 'fresh bread'],
#  ['cake', 'fresh tuna', 'nan'],
#  ['cake', 'mineral water', 'frozen smoothie'],
#  ['cake', 'nan', 'frozen smoothie'],
#  ['cake', 'mineral water', 'frozen vegetables'],
#  ['cake', 'nan', 'frozen vegetables'],
#  ['cake', 'spaghetti', 'frozen vegetables'],
#  ['cake', 'tomatoes', 'frozen vegetables'],
#  ['cake', 'grated cheese', 'nan'],
#  ['cake', 'green tea', 'mineral water'],
#  ['cake', 'nan', 'green tea'],
#  ['cake', 'green tea', 'pancakes'],
#  ['cake', 'mineral water', 'ground beef'],
#  ['cake', 'nan', 'ground beef'],
#  ['cake', 'spaghetti', 'ground beef'],
#  ['cake', 'nan', 'herb & pepper'],
#  ['cake', 'nan', 'honey'],
#  ['cake', 'hot dogs', 'nan'],
#  ['cake', 'nan', 'low fat yogurt'],
#  ['cake', 'mineral water', 'milk'],
#  ['cake', 'nan', 'milk'],
#  ['cake', 'spaghetti', 'milk'],
#  ['cake', 'nan', 'mineral water'],
#  ['cake', 'mineral water', 'olive oil'],
#  ['cake', 'pancakes', 'mineral water'],
#  ['cake', 'soup', 'mineral water'],
#  ['cake', 'spaghetti', 'mineral water'],
#  ['cake', 'mineral water', 'tomatoes'],
#  ['cake', 'mineral water', 'whole wheat rice'],
#  ['cake', 'nan', 'olive oil'],
#  ['cake', 'nan', 'pancakes'],
#  ['cake', 'nan', 'parmesan cheese'],
#  ['cake', 'nan', 'red wine'],
#  ['cake', 'nan', 'salmon'],
#  ['cake', 'nan', 'shrimp'],
#  ['cake', 'nan', 'soup'],
#  ['cake', 'nan', 'spaghetti'],
#  ['cake', 'nan', 'tomato juice'],
#  ['cake', 'nan', 'tomatoes'],
#  ['cake', 'nan', 'turkey'],
#  ['cake', 'nan', 'whole wheat pasta'],
#  ['cake', 'nan', 'whole wheat rice'],
#  ['cake', 'spaghetti', 'olive oil'],
#  ['cake', 'pancakes', 'spaghetti'],
#  ['cake', 'spaghetti', 'tomatoes'],
#  ['nan', 'chocolate', 'carrots'],
#  ['nan', 'green tea', 'carrots'],
#  ['mineral water', 'nan', 'carrots'],
#  ['nan', 'spaghetti', 'carrots'],
#  ['nan', 'cereals', 'chocolate'],
#  ['eggs', 'nan', 'cereals'],
#  ['nan', 'cereals', 'french fries'],
#  ['frozen vegetables', 'nan', 'cereals'],
#  ['nan', 'green tea', 'cereals'],
#  ['nan', 'cereals', 'ground beef'],
#  ['spaghetti', 'cereals', 'ground beef'],
#  ['nan', 'cereals', 'herb & pepper'],
#  ['mineral water', 'cereals', 'milk'],
#  ['nan', 'cereals', 'milk'],
#  ['mineral water', 'nan', 'cereals'],
#  ['mineral water', 'cereals', 'spaghetti'],
#  ['nan', 'pancakes', 'cereals'],
#  ['nan', 'shrimp', 'cereals'],
#  ['nan', 'cereals', 'spaghetti'],
#  ['nan', 'champagne', 'chocolate'],
#  ['cookies', 'nan', 'champagne'],
#  ['nan', 'eggs', 'champagne'],
#  ['nan', 'escalope', 'champagne'],
#  ['nan', 'champagne', 'french fries'],
#  ['nan', 'champagne', 'frozen smoothie'],
#  ['frozen vegetables', 'nan', 'champagne'],
#  ['nan', 'green tea', 'champagne'],
#  ['nan', 'ground beef', 'champagne'],
#  ['nan', 'champagne', 'low fat yogurt'],
#  ['nan', 'champagne', 'milk'],
#  ['mineral water', 'nan', 'champagne'],
#  ['nan', 'pancakes', 'champagne'],
#  ['nan', 'spaghetti', 'champagne'],
#  ['nan', 'champagne', 'whole wheat rice'],
#  ['chicken', 'eggs', 'chocolate'],
#  ['chicken', 'chocolate', 'french fries'],
#  ['green tea', 'chicken', 'chocolate'],
#  ['chicken', 'chocolate', 'milk'],
#  ['mineral water', 'chicken', 'chocolate'],
#  ['nan', 'chicken', 'chocolate'],
#  ['spaghetti', 'chicken', 'chocolate'],
#  ['nan', 'cooking oil', 'chicken'],
#  ['nan', 'cottage cheese', 'chicken'],
#  ['chicken', 'eggs', 'french fries'],
#  ['chicken', 'eggs', 'milk'],
#  ['mineral water', 'chicken', 'eggs'],
#  ['nan', 'chicken', 'eggs'],
#  ['spaghetti', 'chicken', 'eggs'],
#  ['escalope', 'nan', 'chicken'],
#  ['chicken', 'milk', 'french fries'],
#  ['mineral water', 'chicken', 'french fries'],
#  ['nan', 'chicken', 'french fries'],
#  ['spaghetti', 'chicken', 'french fries'],
#  ['nan', 'fresh bread', 'chicken'],
#  ['nan', 'chicken', 'frozen smoothie'],
#  ['frozen vegetables', 'chicken', 'mineral water'],
#  ['frozen vegetables', 'nan', 'chicken'],
#  ['frozen vegetables', 'chicken', 'spaghetti'],
#  ['grated cheese', 'nan', 'chicken'],
#  ['mineral water', 'green tea', 'chicken'],
#  ['nan', 'green tea', 'chicken'],
#  ['spaghetti', 'green tea', 'chicken'],
#  ['chicken', 'ground beef', 'milk'],
#  ['mineral water', 'chicken', 'ground beef'],
#  ['nan', 'chicken', 'ground beef'],
#  ['spaghetti', 'chicken', 'ground beef'],
#  ['nan', 'chicken', 'herb & pepper'],
#  ['honey', 'nan', 'chicken'],
#  ['nan', 'hot dogs', 'chicken'],
#  ['nan', 'chicken', 'light cream'],
#  ['nan', 'chicken', 'low fat yogurt'],
#  ['nan', 'chicken', 'meatballs'],
#  ['mineral water', 'chicken', 'milk'],
#  ['nan', 'chicken', 'milk'],
#  ['chicken', 'olive oil', 'milk'],
#  ['pancakes', 'chicken', 'milk'],
#  ['spaghetti', 'chicken', 'milk'],
#  ['mineral water', 'nan', 'chicken'],
#  ['mineral water', 'chicken', 'olive oil'],
#  ['mineral water', 'chicken', 'pancakes'],
#  ['mineral water', 'chicken', 'soup'],
#  ['mineral water', 'chicken', 'spaghetti'],
#  ['mineral water', 'chicken', 'tomatoes'],
#  ['nan', 'chicken', 'olive oil'],
#  ['nan', 'chicken', 'pancakes'],
#  ['nan', 'chicken', 'salmon'],
#  ['nan', 'shrimp', 'chicken'],
#  ['nan', 'chicken', 'soup'],
#  ['nan', 'chicken', 'spaghetti'],
#  ['nan', 'chicken', 'tomato juice'],
#  ['nan', 'chicken', 'tomatoes'],
#  ['nan', 'chicken', 'turkey'],
#  ['nan', 'whole wheat pasta', 'chicken'],
#  ['nan', 'chicken', 'whole wheat rice'],
#  ['spaghetti', 'chicken', 'olive oil'],
#  ['pancakes', 'chicken', 'spaghetti'],
#  ['cookies', 'chocolate', 'french fries'],
#  ['cookies', 'nan', 'chocolate'],
#  ['cookies', 'spaghetti', 'chocolate'],
#  ['cooking oil', 'eggs', 'chocolate'],
#  ['cooking oil', 'chocolate', 'milk'],
#  ['mineral water', 'cooking oil', 'chocolate'],
#  ['nan', 'cooking oil', 'chocolate'],
#  ['spaghetti', 'cooking oil', 'chocolate'],
#  ['nan', 'cottage cheese', 'chocolate'],
#  ['escalope', 'eggs', 'chocolate'],
#  ['eggs', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'eggs', 'chocolate'],
#  ['green tea', 'eggs', 'chocolate'],
#  ['eggs', 'ground beef', 'chocolate'],
#  ['eggs', 'low fat yogurt', 'chocolate'],
#  ['eggs', 'chocolate', 'milk'],
#  ['mineral water', 'eggs', 'chocolate'],
#  ['nan', 'eggs', 'chocolate'],
#  ['eggs', 'olive oil', 'chocolate'],
#  ['pancakes', 'eggs', 'chocolate'],
#  ['shrimp', 'eggs', 'chocolate'],
#  ['spaghetti', 'eggs', 'chocolate'],
#  ['turkey', 'eggs', 'chocolate'],
#  ['nan', 'energy bar', 'chocolate'],
#  ['nan', 'energy drink', 'chocolate'],
#  ['escalope', 'chocolate', 'french fries'],
#  ['escalope', 'chocolate', 'milk'],
#  ['mineral water', 'escalope', 'chocolate'],
#  ['nan', 'escalope', 'chocolate'],
#  ['spaghetti', 'escalope', 'chocolate'],
#  ['frozen smoothie', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'chocolate', 'french fries'],
#  ['grated cheese', 'chocolate', 'french fries'],
#  ['green tea', 'chocolate', 'french fries'],
#  ['ground beef', 'chocolate', 'french fries'],
#  ['low fat yogurt', 'chocolate', 'french fries'],
#  ['milk', 'chocolate', 'french fries'],
#  ['mineral water', 'chocolate', 'french fries'],
#  ['nan', 'chocolate', 'french fries'],
#  ['olive oil', 'chocolate', 'french fries'],
#  ['pancakes', 'chocolate', 'french fries'],
#  ['shrimp', 'chocolate', 'french fries'],
#  ['spaghetti', 'chocolate', 'french fries'],
#  ['tomatoes', 'chocolate', 'french fries'],
#  ['nan', 'french wine', 'chocolate'],
#  ['mineral water', 'fresh bread', 'chocolate'],
#  ['nan', 'fresh bread', 'chocolate'],
#  ['nan', 'fresh tuna', 'chocolate'],
#  ['nan', 'fromage blanc', 'chocolate'],
#  ['milk', 'chocolate', 'frozen smoothie'],
#  ['mineral water', 'chocolate', 'frozen smoothie'],
#  ['nan', 'chocolate', 'frozen smoothie'],
#  ['spaghetti', 'chocolate', 'frozen smoothie'],
#  ['frozen vegetables', 'green tea', 'chocolate'],
#  ['frozen vegetables', 'ground beef', 'chocolate'],
#  ['frozen vegetables', 'chocolate', 'milk'],
#  ['frozen vegetables', 'mineral water', 'chocolate'],
#  ['frozen vegetables', 'nan', 'chocolate'],
#  ['frozen vegetables', 'olive oil', 'chocolate'],
#  ['frozen vegetables', 'pancakes', 'chocolate'],
#  ['frozen vegetables', 'shrimp', 'chocolate'],
#  ['frozen vegetables', 'spaghetti', 'chocolate'],
#  ['frozen vegetables', 'tomatoes', 'chocolate'],
#  ['grated cheese', 'mineral water', 'chocolate'],
#  ['grated cheese', 'nan', 'chocolate'],
#  ['grated cheese', 'spaghetti', 'chocolate'],
#  ['green tea', 'ground beef', 'chocolate'],
#  ['green tea', 'chocolate', 'milk'],
#  ['mineral water', 'green tea', 'chocolate'],
#  ['nan', 'green tea', 'chocolate'],
#  ['pancakes', 'green tea', 'chocolate'],
#  ['spaghetti', 'green tea', 'chocolate'],
#  ['herb & pepper', 'ground beef', 'chocolate'],
#  ['ground beef', 'chocolate', 'milk'],
#  ['mineral water', 'ground beef', 'chocolate'],
#  ['nan', 'ground beef', 'chocolate'],
#  ['olive oil', 'ground beef', 'chocolate'],
#  ['pancakes', 'ground beef', 'chocolate'],
#  ['shrimp', 'ground beef', 'chocolate'],
#  ['spaghetti', 'ground beef', 'chocolate'],
#  ['nan', 'ham', 'chocolate'],
#  ['herb & pepper', 'mineral water', 'chocolate'],
#  ['herb & pepper', 'nan', 'chocolate'],
#  ['honey', 'mineral water', 'chocolate'],
#  ['honey', 'nan', 'chocolate'],
#  ['nan', 'hot dogs', 'chocolate'],
#  ['nan', 'chocolate', 'light cream'],
#  ['nan', 'light mayo', 'chocolate'],
#  ['low fat yogurt', 'chocolate', 'milk'],
#  ['mineral water', 'low fat yogurt', 'chocolate'],
#  ['nan', 'low fat yogurt', 'chocolate'],
#  ['spaghetti', 'low fat yogurt', 'chocolate'],
#  ['mineral water', 'chocolate', 'milk'],
#  ['nan', 'chocolate', 'milk'],
#  ['olive oil', 'chocolate', 'milk'],
#  ['pancakes', 'chocolate', 'milk'],
#  ['shrimp', 'chocolate', 'milk'],
#  ['soup', 'chocolate', 'milk'],
#  ['spaghetti', 'chocolate', 'milk'],
#  ['tomatoes', 'chocolate', 'milk'],
#  ['turkey', 'chocolate', 'milk'],
#  ['mineral water', 'nan', 'chocolate'],
#  ['mineral water', 'olive oil', 'chocolate'],
#  ['mineral water', 'pancakes', 'chocolate'],
#  ['mineral water', 'salmon', 'chocolate'],
#  ['mineral water', 'shrimp', 'chocolate'],
#  ['mineral water', 'soup', 'chocolate'],
#  ['mineral water', 'spaghetti', 'chocolate'],
#  ['mineral water', 'tomatoes', 'chocolate'],
#  ['mineral water', 'turkey', 'chocolate'],
#  ['mineral water', 'whole wheat rice', 'chocolate'],
#  ['nan', 'mint', 'chocolate'],
#  ['muffins', 'nan', 'chocolate'],
#  ['nan', 'mushroom cream sauce', 'chocolate'],
#  ['nan', 'oil', 'chocolate'],
#  ['nan', 'olive oil', 'chocolate'],
#  ['nan', 'pancakes', 'chocolate'],
#  ['nan', 'parmesan cheese', 'chocolate'],
#  ['nan', 'pepper', 'chocolate'],
#  ['nan', 'chocolate', 'protein bar'],
#  ['nan', 'red wine', 'chocolate'],
#  ['nan', 'chocolate', 'rice'],
#  ['nan', 'salmon', 'chocolate'],
#  ['nan', 'shrimp', 'chocolate'],
#  ['nan', 'soup', 'chocolate'],
#  ['nan', 'spaghetti', 'chocolate'],
#  ['nan', 'chocolate', 'strawberries'],
#  ['nan', 'chocolate', 'tomato juice'],
#  ['nan', 'tomato sauce', 'chocolate'],
#  ['nan', 'tomatoes', 'chocolate'],
#  ['nan', 'turkey', 'chocolate'],
#  ['nan', 'vegetables mix', 'chocolate'],
#  ['nan', 'white wine', 'chocolate'],
#  ['nan', 'whole wheat pasta', 'chocolate'],
#  ['nan', 'whole wheat rice', 'chocolate'],
#  ['nan', 'yogurt cake', 'chocolate'],
#  ['pancakes', 'olive oil', 'chocolate'],
#  ['spaghetti', 'olive oil', 'chocolate'],
#  ['spaghetti', 'pancakes', 'chocolate'],
#  ['spaghetti', 'salmon', 'chocolate'],
#  ['spaghetti', 'shrimp', 'chocolate'],
#  ['spaghetti', 'soup', 'chocolate'],
#  ['spaghetti', 'tomatoes', 'chocolate'],
#  ['spaghetti', 'turkey', 'chocolate'],
#  ['spaghetti', 'whole wheat rice', 'chocolate'],
#  ['nan', 'eggs', 'cider'],
#  ['nan', 'cider', 'milk'],
#  ['cookies', 'nan', 'eggs'],
#  ['cookies', 'green tea', 'french fries'],
#  ['cookies', 'nan', 'french fries'],
#  ['cookies', 'nan', 'frozen smoothie'],
#  ['cookies', 'nan', 'green tea'],
#  ['cookies', 'nan', 'ground beef'],
#  ['cookies', 'nan', 'low fat yogurt'],
#  ['cookies', 'nan', 'milk'],
#  ['cookies', 'nan', 'mineral water'],
#  ['cookies', 'nan', 'pancakes'],
#  ['cookies', 'nan', 'shrimp'],
#  ['cookies', 'nan', 'spaghetti'],
#  ['cookies', 'nan', 'whole wheat rice'],
#  ['cooking oil', 'eggs', 'milk'],
#  ['mineral water', 'cooking oil', 'eggs'],
#  ['nan', 'cooking oil', 'eggs'],
#  ['spaghetti', 'cooking oil', 'eggs'],
#  ['nan', 'cooking oil', 'escalope'],
#  ['nan', 'cooking oil', 'french fries'],
#  ['nan', 'cooking oil', 'frozen smoothie'],
#  ['frozen vegetables', 'cooking oil', 'nan'],
#  ['grated cheese', 'cooking oil', 'nan'],
#  ['mineral water', 'cooking oil', 'green tea'],
#  ['nan', 'cooking oil', 'green tea'],
#  ['mineral water', 'cooking oil', 'ground beef'],
#  ['nan', 'cooking oil', 'ground beef'],
#  ['spaghetti', 'cooking oil', 'ground beef'],
#  ['nan', 'cooking oil', 'herb & pepper'],
#  ['honey', 'cooking oil', 'nan'],
#  ['nan', 'cooking oil', 'low fat yogurt'],
#  ['mineral water', 'cooking oil', 'milk'],
#  ['nan', 'cooking oil', 'milk'],
#  ['spaghetti', 'cooking oil', 'milk'],
#  ['mineral water', 'cooking oil', 'nan'],
#  ['mineral water', 'cooking oil', 'pancakes'],
#  ['mineral water', 'cooking oil', 'spaghetti'],
#  ['nan', 'cooking oil', 'olive oil'],
#  ['nan', 'cooking oil', 'pancakes'],
#  ['nan', 'cooking oil', 'salmon'],
#  ['nan', 'cooking oil', 'shrimp'],
#  ['nan', 'cooking oil', 'soup'],
#  ['nan', 'cooking oil', 'spaghetti'],
#  ['nan', 'cooking oil', 'tomatoes'],
#  ['nan', 'cooking oil', 'turkey'],
#  ['nan', 'cooking oil', 'whole wheat rice'],
#  ['nan', 'cottage cheese', 'eggs'],
#  ['nan', 'cottage cheese', 'french fries'],
#  ['nan', 'cottage cheese', 'frozen smoothie'],
#  ['frozen vegetables', 'cottage cheese', 'nan'],
#  ['nan', 'cottage cheese', 'green tea'],
#  ['nan', 'cottage cheese', 'ground beef'],
#  ['nan', 'cottage cheese', 'milk'],
#  ['mineral water', 'cottage cheese', 'nan'],
#  ['mineral water', 'cottage cheese', 'spaghetti'],
#  ['nan', 'cottage cheese', 'olive oil'],
#  ['nan', 'cottage cheese', 'pancakes'],
#  ['nan', 'cottage cheese', 'spaghetti'],
#  ['nan', 'eggs', 'eggplant'],
#  ['mineral water', 'nan', 'eggplant'],
#  ['nan', 'spaghetti', 'eggplant'],
#  ['nan', 'energy bar', 'eggs'],
#  ['nan', 'eggs', 'energy drink'],
#  ['mineral water', 'escalope', 'eggs'],
#  ['nan', 'escalope', 'eggs'],
#  ['frozen vegetables', 'eggs', 'french fries'],
#  ['green tea', 'eggs', 'french fries'],
#  ['eggs', 'ground beef', 'french fries'],
#  ['eggs', 'low fat yogurt', 'french fries'],
#  ['eggs', 'milk', 'french fries'],
#  ['mineral water', 'eggs', 'french fries'],
#  ['nan', 'eggs', 'french fries'],
#  ['pancakes', 'eggs', 'french fries'],
#  ['spaghetti', 'eggs', 'french fries'],
#  ['tomatoes', 'eggs', 'french fries'],
#  ['eggs', 'turkey', 'french fries'],
#  ['nan', 'french wine', 'eggs'],
#  ['mineral water', 'fresh bread', 'eggs'],
#  ['nan', 'fresh bread', 'eggs'],
#  ['nan', 'fresh tuna', 'eggs'],
#  ['nan', 'eggs', 'fromage blanc'],
#  ['mineral water', 'eggs', 'frozen smoothie'],
#  ['nan', 'eggs', 'frozen smoothie'],
#  ['frozen vegetables', 'green tea', 'eggs'],
#  ['frozen vegetables', 'eggs', 'ground beef'],
#  ['frozen vegetables', 'eggs', 'low fat yogurt'],
#  ['frozen vegetables', 'eggs', 'milk'],
#  ['frozen vegetables', 'eggs', 'mineral water'],
#  ['frozen vegetables', 'nan', 'eggs'],
#  ['frozen vegetables', 'pancakes', 'eggs'],
#  ['frozen vegetables', 'shrimp', 'eggs'],
#  ['frozen vegetables', 'eggs', 'spaghetti'],
#  ['frozen vegetables', 'eggs', 'tomatoes'],
#  ['grated cheese', 'eggs', 'mineral water'],
#  ['grated cheese', 'nan', 'eggs'],
#  ['grated cheese', 'eggs', 'spaghetti'],
#  ['green tea', 'eggs', 'milk'],
#  ['mineral water', 'green tea', 'eggs'],
#  ['nan', 'green tea', 'eggs'],
#  ['pancakes', 'green tea', 'eggs'],
#  ['spaghetti', 'green tea', 'eggs'],
#  ['green tea', 'eggs', 'turkey'],
#  ['eggs', 'ground beef', 'herb & pepper'],
#  ['eggs', 'ground beef', 'milk'],
#  ['mineral water', 'eggs', 'ground beef'],
#  ['nan', 'eggs', 'ground beef'],
#  ['spaghetti', 'eggs', 'ground beef'],
#  ['nan', 'ham', 'eggs'],
#  ['eggs', 'herb & pepper', 'milk'],
#  ['mineral water', 'eggs', 'herb & pepper'],
#  ['nan', 'eggs', 'herb & pepper'],
#  ['spaghetti', 'eggs', 'herb & pepper'],
#  ['honey', 'nan', 'eggs'],
#  ['nan', 'hot dogs', 'eggs'],
#  ['nan', 'eggs', 'light cream'],
#  ['nan', 'light mayo', 'eggs'],
#  ['eggs', 'low fat yogurt', 'milk'],
#  ['mineral water', 'eggs', 'low fat yogurt'],
#  ['nan', 'eggs', 'low fat yogurt'],
#  ['spaghetti', 'eggs', 'low fat yogurt'],
#  ...]
