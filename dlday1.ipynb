# %%
# Introduction to Deep Learning  ====>

# Artificial Neurons

# Input_layer ----> Hidden_layer ----> Target_layer

# %%
# WorkFlow of Machine Learning ===>

# Data Gathering ===> Data Cleaning and Pre-processing ----> Select Machine Learning Model according to
# target column -----> Train the Model ----> Prediction the Model ----> Find Accuracy .

# %%
# WorkFlow of Deep Learning ---->
# Data Gathering ----> Data Cleaning and Pre-processing ---> Create a Model Architecture
# Input_layer(neurons , activation_function , total_number_of_columns)  ,
# Hidden_layer(neuorns , activation_function) ,
# Output_layer(neurons_based_on_target_data , activation_function_based_on_target_data)
# Model_compile(optimizer , loss_function , metrics_score),
# Model.fit(x_train , y_train , epochs....)
# Model_Prediction
# Calculate_loss_and_Accuracy .

# %%
# Activation_function ===> Mathematical function who convert our data into a scaled format .
# Step_function ===> if (val>0): return1 else :return 0
# Sigmoid_function ==>Probability based ===> threshold value(0.5 or 1/2) ==> if(val>0.5):return 1 else :return 0
# Tanh_function ===> if (val>0): return 1 else : return -1
# Relu_function ===> Used when we have to reduce overfitting of our data . ==> if(val>0):return 0elif(val<0): x*val

# %%
# loss_function ===> Actual_value - Predicted_value
# Categorical --->when we have 2 sub-categories ---> BinaryCrossEntroy Loss function .
# Categorical ---> when we have more than 2 sub-categories ---> SparseCategoricalCross Entropy Loss function .

# %%
# Optimizers ----> Reduce Loss function .
# (1). StocasticGradient Descent ---> elements local minima stuck .
# (2). SGD + Mometum  ---> elements reduce stucking in local minima. . in general = 0.9
# (3). SGD+Momemtum+NAG ---> solve complete problem of stucking in local minima.
# (4). AdaGrad ---> Automate learning eate but problem gradient exploading and vanishing gradient .
# (5). RMSProp ----> Solve issue of automatic learning rate .
# (6). Adam ---> (Momentum + RMSProp) ----> Best Optimizer .

# %%
import numpy as np
import pandas as pd

# %%
df=  pd.read_csv("/content/Attrition.csv")
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.metrics import accuracy_score

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
x = df.drop(columns = ['Attrition'] , axis=1)
y = df['Attrition']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
categorical_features = ['BusinessTravel',
                       'Department',
                       'EducationField',
                       'Gender',
                       'JobRole',
                       'MaritalStatus',
                       'Over18',
                       'OverTime']

# %%
x_encoded = pd.get_dummies(x, columns = categorical_features ,
                           drop_first = True)

# %%
# x_encoded.dtypes

# %%
x_encoded = x_encoded.astype(int)

# %%
x_encoded
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
# encode target data
lb = LabelEncoder()

# %%
y_encoded = lb.fit_transform(y)
y_encoded
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
x_train , x_test , y_train , y_test = train_test_split(x_encoded ,
                                                      y_encoded ,
                                                      test_size  = 0.2 ,
                                                       random_state = 42)

# %%
sc = StandardScaler()

# %%
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %% [markdown]
# Now we will create our Architecture

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units = 128 , activation = 'relu' ,
                          input_dim = x_train_scaled.shape[1]),  #input layer
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(units = 64 , activation = 'relu'),    #hidden layer
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(units = 1 , activation = 'sigmoid')   #output layer
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy()
metrics = ['accuracy']

# %%
learning_rate = 0.001
momentum = 0.9
optimizer = tf.keras.optimizers.SGD(learning_rate = learning_rate ,
                                    momentum = momentum , nesterov = True)

# %%
model.compile(optimizer = optimizer , loss = loss_fn , metrics = metrics)

# %%
model.fit(x_train_scaled ,
         y_train ,
         epochs = 50 ,
          batch_size = 8 ,
          validation_split = 0.1

         )
# Out:
# Epoch 1/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7749 - loss: 0.5662 - val_accuracy: 0.7966 - val_loss: 0.5120
# Epoch 2/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8439 - loss: 0.4761 - val_accuracy: 0.7966 - val_loss: 0.4776
# Epoch 3/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8537 - loss: 0.4334 - val_accuracy: 0.7966 - val_loss: 0.4537
# Epoch 4/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8521 - loss: 0.3932 - val_accuracy: 0.7966 - val_loss: 0.4407
# Epoch 5/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8544 - loss: 0.3641 - val_accuracy: 0.8220 - val_loss: 0.4276
# Epoch 6/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.4100 - val_accuracy: 0.8051 - val_loss: 0.4208
# Epoch 7/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8528 - loss: 0.3627 - val_accuracy: 0.8390 - val_loss: 0.4076
# Epoch 8/50
# ...

# %%
loss , accuracy = model.evaluate(x_test_scaled , y_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8766 - loss: 0.3577

# %%
print(f'Test Loss = {loss:.4f} , Test Accuracy = {accuracy:.4f}')
# Out:
# Test Loss = 0.3598 , Test Accuracy = 0.8741
